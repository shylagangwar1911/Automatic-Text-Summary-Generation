# %%
# !pip install PyDrive
# !pip install rouge
# !pip install pytorch-pretrained-bert
# Out:
# Collecting PyDrive
#   Downloading https://files.pythonhosted.org/packages/52/e0/0e64788e5dd58ce2d6934549676243dc69d982f198524be9b99e9c2a4fd5/PyDrive-1.3.1.tar.gz (987kB)
#     100% |████████████████████████████████| 993kB 25.4MB/s
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.12.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.5)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.4)
# Building wheels for collected packages: PyDrive
#   Building wheel for PyDrive (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# Installing collected packages: PyDrive
# Successfully installed PyDrive-1.3.1
# Collecting rouge
#   Downloading https://files.pythonhosted.org/packages/63/ac/b93411318529980ab7f41e59ed64ec3ffed08ead32389e29eb78585dd55d/rouge-0.3.2-py3-none-any.whl
# Installing collected packages: rouge
# Successfully installed rouge-0.3.2
# Collecting pytorch-pretrained-bert
#   Downloading https://files.pythonhosted.org/packages/d7/e0/c08d5553b89973d9a240605b9c12404bcf8227590de62bae27acbcfe076b/pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123kB)
#     100% |████████████████████████████████| 133kB 1.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (1.16.3)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (1.9.134)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (2.21.0)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (1.0.1.post2)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (2018.1.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pytorch-pretrained-bert) (4.28.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert) (0.2.0)
# Requirement already satisfied: botocore<1.13.0,>=1.12.134 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-pretrained-bert) (1.12.134)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-pretrained-bert) (2019.3.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.134->boto3->pytorch-pretrained-bert) (2.5.3)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.134->boto3->pytorch-pretrained-bert) (0.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.13.0,>=1.12.134->boto3->pytorch-pretrained-bert) (1.12.0)
# Installing collected packages: pytorch-pretrained-bert
# Successfully installed pytorch-pretrained-bert-0.6.2

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import json, gzip
import torch
import torch.nn as nn
import numpy as np
import time
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import drive
from oauth2client.client import GoogleCredentials
import pickle
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM, BasicTokenizer
import logging
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
print(torch.__version__)
# Out:
# 1.0.1.post2

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '1QZvEiZeKtyuDFxkuWL_Jbv_GpQTlKIco'})
download.GetContentFile('train.jsonl.gz')

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
path = "train.jsonl.gz"
data = []
with gzip.open(path) as f:
    for ln in f:
        t = json.loads(ln.decode('utf-8'))
        text = t['text']
        tokenized_text = tokenizer.tokenize(text).copy()
        l = len(tokenized_text)
        if l > 512:
            continue
#         print(l)  
        summ = t['summary']
        tokenized_summ = tokenizer.tokenize(summ)
        s = len(tokenized_summ)
        if s > 512:
            continue
        data.append(t)
        if(len(data)>=100):
            break
print(len(data))
train_dict = data
# Out:
# 100

# %%
print(train_dict[0]['text'])
# Out:
# Spinach has terrorized generations of veggie-phobic kids, and many grownups don't much like it, either. But when it's combined with seasonings and feta cheese and wrapped in a golden crisp phyllo dough crust, even those who despise Popeye's Â­favorite food ask for seconds.
#
# The spinach pie at Kebab House II on Orchard St. is a specialty of owner and executive chef Ramazan Ay, who serves the hearty dish as a main course. You can make individual tarts or one large pie, though the small ones are more labor-intensive. If you've never worked with phyllo dough before, know that it is important to keep the part you are not using covered with a damp towel so it won't dry out. Other than that, this dish is a snap to make - and a favorite in my family, even among those who eschew anything green.
#
# 1 onion, peeled and chopped
#
# 2 cups crumbled feta cheese
#
# Salt and pepper to taste
#
# 1 pound phyllo dough, thawed if frozen
#
# Preheat the oven to 400 degrees. In a sautÃ© pan, heat the olive oil over low heat. SautÃ© the spinach and onion for 10 minutes. Mix in the cheese, salt and pepper.
#
# Lay out a piece of phyllo dough and paint it with a little olive oil. Place a small portion of filling into the center, and fold over several times to enclose the filling completely. Repeat with remaining phyllo until all the filling is used up. Bake for 25- 30 minutes or until golden brown.
#
# Look for phyllo dough in the supermarket freezer case. Once thawed, it can successfully be refrozen.
#
# Optional flavorings for the filling include a grating of fresh nutmeg and some chopped fresh dill.
#
# You can freeze spinach pie, well wrapped, for up to three months.

# %%
train_dict = sorted(train_dict, key = lambda i: len(i['text']), reverse = True)

# %%
mx = 0
count  = 0
for t in train_dict:
    text = t['text']
    tokenized_text = tokenizer.tokenize(text).copy()
    l = len(tokenized_text)
    if l > mx:
        mx = l
    summ = t['summary']
    tokenized_summ = tokenizer.tokenize(summ).copy()
    s = len(tokenized_summ)
    if s> count:
        count = s
print(mx)
print(count)
# Out:
# 499
# 156

# %%
mx = 0
count  = 0

text_seq_len = 499
s_seq_len = 156
batch_size = 100
text_tensor = torch.zeros([batch_size, text_seq_len ], dtype=torch.int32)
summ_tensor = torch.zeros([batch_size, s_seq_len ], dtype=torch.int32)
pad_len_tensor = torch.zeros([batch_size], dtype=torch.int32)
i = 0
for t in train_dict:
#   print(t)
    text = t['text']
    tokenized_text = tokenizer.tokenize(text)
    l = len(tokenized_text)
    summ = t['summary']
    tokenized_summ = tokenizer.tokenize(summ)
    s = len(tokenized_summ)
    if l>=s:
        if l<text_seq_len:
            pad = ['[PAD]' ] * (text_seq_len-l)
            tokenized_text += pad 
            pad_len_tensor[i] = text_seq_len-l
        if s<s_seq_len:
            pad = ['[PAD]' ] * (s_seq_len-s)
            tokenized_summ += pad
        if s > mx:
            mx = s
        indexed_tokens_t = tokenizer.convert_tokens_to_ids(tokenized_text) 
        indexed_tokens_s = tokenizer.convert_tokens_to_ids(tokenized_summ)
        tokens_tensor_t = torch.tensor(indexed_tokens_t)
        text_tensor[i] =  tokens_tensor_t
        tokens_tensor_s = torch.tensor(indexed_tokens_s)
        summ_tensor[i] = tokens_tensor_s
        i+=1
model = BertModel.from_pretrained('bert-base-uncased')
model.eval()  
text_tensor = text_tensor.long().to('cuda')
summ_tensor = summ_tensor.long().to('cuda')
pad_len_tensor = pad_len_tensor.long().to('cuda')
model.to('cuda')
with torch.no_grad():
    encoded_layers_t, _ = model(text_tensor, output_all_encoded_layers=False)
    encoded_layers_s, _ = model(summ_tensor, output_all_encoded_layers=False)
print(encoded_layers_t.size())
print(encoded_layers_s.size()) 
print(pad_len_tensor.size())
print(mx)
# Out:
# torch.Size([100, 499, 768])
# torch.Size([100, 156, 768])
# torch.Size([100])
# 156

# %%
class biEncoderLSTM(nn.Module):
    
    def __init__(self, params):
        super(biEncoderLSTM, self).__init__()
        self.hidden_size = params['hidden_size']
        self.emb_size = params['emb_size']
        self.vocab_size = params['vocab_size']
        self.num_layers = params['num_layers']
        self.embedding = nn.Embedding(self.vocab_size, self.emb_size)
        self.lstm = nn.LSTM(self.emb_size, self.hidden_size, batch_first = True, num_layers=self.num_layers, bidirectional = True)

    def forward(self, input, hidden, memory, seq_lengths):
        batch, seq_len, emb_size = input.size()
        emb = input
#         packed_emb = pack_padded_sequence(emb, (seq_lengths).cpu().numpy(), batch_first = True)
#         packed_output, (h, c) = self.lstm(packed_emb, (hidden, memory))
#         output, _ = pad_packed_sequence(packed_output, batch_first = True)
        output, (h, c) = self.lstm(emb, (hidden, memory))
        output1 = output[ :, :, :self.hidden_size]
        output2 = output[:, :, self.hidden_size:] #reverse
        output = output1+output2
        h = h.view(self.num_layers, 2, batch, self.hidden_size)
        c = c.view(self.num_layers, 2, batch, self.hidden_size)
        h = h[:,0,:,:]
        c = c[:,0,:,:]
        return output, h, c

    def initHidden(self, batch_size):
        h_init = torch.randn(self.num_layers*2, batch_size, self.hidden_size).cuda()
        c_init = torch.randn(self.num_layers*2, batch_size, self.hidden_size).cuda()
        return h_init, c_init

# %%
class DecoderLSTM(nn.Module):
    
    def __init__(self, params):
        super(DecoderLSTM, self).__init__()
        self.hidden_size = params['hidden_size']
        self.vocab_size = params['vocab_size']
        self.emb_size = params['emb_size']
        self.num_layers = params['num_layers']
        self.embedding = nn.Embedding(self.vocab_size, self.emb_size)
        self.lstm = nn.LSTM(self.emb_size, self.hidden_size, batch_first = True)
        self.w = nn.Linear(self.hidden_size, self.vocab_size)

    def forward(self, input, hidden, memory):
        batch_size, seq_len = input.size()
        emb = self.embedding(input)
        output, (h, c) = self.lstm(emb, (hidden, memory))
        logits = self.w(output)
        return logits, h, c

    def initHidden(self):
        h_init = torch.randn(self.num_layers, batch_size, self.d_hid).cuda()
        c_init = torch.randn(self.num_layers, batch_size, self.d_hid).cuda()
        return h_init, c_init

# %%
class AttnDecoderLSTM(nn.Module):
    
    def __init__(self, params):
        super(AttnDecoderLSTM, self).__init__()
        self.hidden_size = params['hidden_size']
        self.vocab_size = params['vocab_size']
        self.emb_size = params['emb_size']
        self.num_layers = params['num_layers']
        self.batch_size = params['batch_size']
        #self.dropout_p = params['dropout_p']

        self.embedding = nn.Embedding(self.vocab_size, self.hidden_size)
        #self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        #self.dropout = nn.Dropout(self.dropout_p)
        self.lstm = nn.LSTM(self.emb_size, self.hidden_size, batch_first=True, num_layers = self.num_layers)
        self.w = nn.Linear(2*self.hidden_size, self.vocab_size)

    def forward(self, input, hidden, memory, encoder_outputs, pad_ind):
        batch_size, seq_len, emb_size = input.size()
        embedded = input
        #embedded = self.dropout(embedded)
        
        output,(h,c) = self.lstm(embedded, (hidden, memory))
        
        attn_values = torch.bmm(output,encoder_outputs.permute(0,2,1))
        dec_attn_values = torch.bmm(output,output.permute(0,2,1))
    
        for b in range(batch_size):
            attn_values[b,:,pad_ind[b]:] = -1e10
        
        mask = torch.ones_like(dec_attn_values).cuda()
        mask1 = -1e10*torch.ones_like(dec_attn_values).cuda()
        
        mask = torch.tril(mask, diagonal = -1)
        mask1 = torch.triu(mask1)
        mask = mask+mask1
        dec_attn_values = dec_attn_values*mask.float()
        
        total_attn_values = torch.cat((attn_values,dec_attn_values),2)
        total_outputs = torch.cat((encoder_outputs,output),1)
        
        sftmax = nn.Softmax(dim=2)
        total_attn_weights = sftmax(total_attn_values)
        weight_attn = torch.bmm(total_attn_weights, total_outputs)
        final_hidden = torch.cat((output,weight_attn),2)
        scores = self.w(final_hidden)
        return scores, h, c


    def initHidden(self, batch_size):
        h_init = torch.randn(self.num_layers, batch_size, self.hidden_size).cuda()
        c_init = torch.randn(self.num_layers, batch_size, self.hidden_size).cuda()
        return h_init, c_init

# %%
from rouge import Rouge

def calculate_rouge (hyps, refs):
    #print(hyps, refs)
    r = Rouge()
    scores = r.get_scores(hyps, refs, avg=True)
    return(scores)

# %%
def train_lm(encoded_layers_t, encoded_layers_s, pad_len_tensor, summ_tensor, params, net, fscore = True):
    
    # since the first index corresponds to the PAD token, we just ignore it
    # when computing the loss
    criterion = nn.CrossEntropyLoss(ignore_index=0)
    sftmax = nn.Softmax(dim=2)
    optimizer = optim.Adam(net.parameters(), lr=params['learning_rate'])
    num_examples = encoded_layers_t.size()[0]    
    batches = [(start, start + params['batch_size']) for start in range(0, num_examples, params['batch_size'])]
    
    for epoch in range(params['epochs']):
        ep_loss = 0.
        start_time = time.time()
        #random.shuffle(batches)
        ref_summ = []
        gen_summ = []
        count = 0
        # for each batch, calculate loss and optimize model parameters            
        for b_idx, (start, end) in enumerate(batches):
            batch_text = encoded_layers_t[start:end]
            batch_summary = encoded_layers_s[start:end]
            batch_pad_len = pad_len_tensor[start:end]
            tar = summ_tensor[start:end]
            
            pred = net(batch_text, batch_summary, batch_pad_len)
            preds = pred[:, :-1, :].contiguous().view(-1, net.vocab_size)
            
            targets = tar[:, 1:].contiguous().view(-1)
            loss = criterion(preds, targets)
            
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            ep_loss += loss
        
        if fscore:
                logits = sftmax(pred)
                words = torch.argmax(logits, dim=2)
                for sent in range(words.size()[0]):
                    summ = ''
                    gold = ''
                    for word in range(words.size()[1]):
                        if tokenizer.convert_ids_to_tokens([words[sent][word].item()])[0] == 'EOS':
                            break
                        if summ :
                            summ += ' '
                        summ += tokenizer.convert_ids_to_tokens([words[sent][word].item()])[0]

                    for word in range(1,len(summ_tensor[sent])-1):
                        if tokenizer.convert_ids_to_tokens([summ_tensor[sent][word].item()])[0] == 'EOS':
                            break
                        if gold:
                            gold += ' '
                        gold += tokenizer.convert_ids_to_tokens([summ_tensor[sent][word].item()])[0]

                    if summ == '.'*len(summ):
                        count += 1
                    if not summ or summ == '.'*len(summ):
                        summ = '====='

                    gen_summ.append(summ)
                    ref_summ.append(gold)
        
        ind = 0
        scores = pred[ind,:,:].unsqueeze(0)
        logits = sftmax(scores)
        words = torch.argmax(logits, dim=2).squeeze(0)
        gold_summ_last = ''
        summ_last = ''
        for l in range(summ_tensor[ind,1:].size()[0]):
            gold_summ_last += tokenizer.convert_ids_to_tokens([summ_tensor[ind,l].item()])[0] + ' '
        for l in range(words.size()[0]):
            summ_last += tokenizer.convert_ids_to_tokens([words[l].item()])[0] + ' '
        print('########################Train######################')
        print(gold_summ_last)
        print(summ_last)
        
        if fscore:
            rouge_score = calculate_rouge(gen_summ, ref_summ)
            print('rouge', rouge_score)
        print('epoch: %d, loss: %0.2f, time: %0.2f sec' %\
              (epoch, ep_loss, time.time()-start_time))
        print('####################################################')

# %%
# function to evaluate LM perplexity on some input data, DO NOT MODIFY
def compute_loss(dataset, net, bsz=10, fscore = False):
    
    sftmax= nn.Softmax(dim=2)
    criterion = nn.CrossEntropyLoss(ignore_index=0)
    num_examples = len(dataset)  
    # we'll still use batches b/c we can't fit the whole
    # validation set into GPU memory
    batches = [(start, start + bsz) for start in range(0, num_examples, bsz)]
    
    total_unmasked_tokens = 0. # count how many unpadded tokens there are
    nll = 0.
    gen_summ = []
    ref_summ = []
    
    for b_idx, (start, end) in enumerate(batches):
            
        batch = dataset[start:end]
        batch_text = np.zeros([len(batch), len(batch[0]['text'])])
        batch_summary = np.zeros([len(batch), len(batch[0]['summary'])])
        batch_pad_len = np.zeros([len(batch)])
        i = 0
        for d in batch:
            batch_text[i] = d['text']
            batch_summary[i] = d['summary']
            batch_pad_len[i] = d['text_len']
            i += 1
        batch_text = torch.from_numpy(batch_text).long().cuda()
        batch_summary = torch.from_numpy(batch_summary).long().cuda()
        batch_pad_len = torch.from_numpy(batch_pad_len).long().cuda()
            
        ut = torch.nonzero(batch_text).size(0)
        pred = net(batch_text, batch_summary, batch_pad_len)
        targets = batch_summary[:, 1:].contiguous().view(-1)
        preds = pred[:, :-1, :].contiguous().view(-1, net.vocab_size)
        loss = criterion(preds, targets)
        nll += loss.detach()
        total_unmasked_tokens += ut
        
        if fscore:
            #print('pred', pred.size())
            logits = sftmax(pred)
            words = torch.argmax(logits, dim=2)
            #print('words', words.size())
            for sent in range(words.size()[0]):
                summ = ''
                gold = ''
                for word in range(words.size()[1]):
                    if index2word[words[sent][word].item()] == 'EOS':
                        break
                    if summ :
                        summ += ' '
                    summ += index2word[words[sent][word].item()]

                for word in range(1,len(batch_summary[sent])-1):
                    if index2word[batch_summary[sent][word].item()] == 'EOS':
                        break
                    if gold:
                        gold += ' '
                    gold += index2word[batch_summary[sent][word].item()]

                if summ == '.'*len(summ):
                    count += 1
                if not summ or summ == '.'*len(summ):
                    summ = '====='

                gen_summ.append(summ)
                ref_summ.append(gold)
        
    
    scores = pred[14,:,:].unsqueeze(0)
    logits = sftmax(scores)
    words = torch.argmax(logits, dim=2).squeeze(0)
    gold_summ = ''
    summ = ''
    for l in range(batch_summary[14,1:].size()[0]):
        gold_summ += index2word[batch_summary[14,l].item()] + ' '
    for l in range(words.size()[0]):
        summ += index2word[words[l].item()] + ' '
            
    
    print('#############Dev###########')
    if fscore:
        rouge_score = calculate_rouge(gen_summ, ref_summ)
        print('rouge', rouge_score)
    print(gold_summ)
    print(summ)
    
    perplexity = torch.exp(nll / total_unmasked_tokens).cpu()
    return nll, perplexity.data

# %%
class SuperAwesome(nn.Module):
    def __init__(self, params):
        super(SuperAwesome, self).__init__()
        #self.enc = EncoderLSTM(params).cuda()
        self.bienc = biEncoderLSTM(params).cuda()
        #self.dc = DecoderLSTM(params).cuda()
        self.attn_dc = AttnDecoderLSTM(params).cuda()
        self.vocab_size = params['vocab_size']
    def forward(self, batch_text, batch_summary, batch_pad_len):
        batch_size, seq_size, emd_size = batch_text.size()
        
#         h_init,c_init = self.enc.initHidden(batch_size)
#         enc_output,h_enc,c_enc = self.enc(batch_text,h_init,c_init, batch_pad_len)
        
        h_init,c_init = self.bienc.initHidden(batch_size)
        enc_output,h_enc,c_enc = self.bienc(batch_text,h_init,c_init, batch_pad_len)
        #h_init,c_init = self.attn_dc.initHidden(batch_size)
        h_init, c_init = h_enc.contiguous(),c_enc.contiguous()
        attn_pre,h,c = self.attn_dc(batch_summary,h_init,c_init,enc_output, batch_pad_len)
#         attn_pre, h, c = self.dc(batch_summary, h_enc, c_enc)
        return attn_pre

# %%
params = {}
params['hidden_size'] = 512
params['emb_size'] = 768
params['num_layers'] = 1
params['batch_size'] = 1
params['vocab_size'] = 30522
params['learning_rate'] = 0.001
params['epochs'] = 500
net = SuperAwesome(params)

train_lm(encoded_layers_t, encoded_layers_s,pad_len_tensor, summ_tensor, params, net, fscore = True)
# Out:
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# rouge {'rouge-1': {'f': 0.02222222200246914, 'p': 1.0, 'r': 0.011235955056179775}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.011237357618054918, 'p': 1.0, 'r': 0.011235955056179775}}
# epoch: 0, loss: 840.54, time: 10.31 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# golden the the the the the the the , , , , , the , , , , , , , the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the , the the , the , , , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.06521739067344046, 'p': 1.0, 'r': 0.033707865168539325}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.03374487231133442, 'p': 1.0, 'r': 0.033707865168539325}}
# epoch: 1, loss: 648.16, time: 10.24 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# broke the the the the the the the , , the , , the , the , the , , , the the the the the the the the the the the the the the the the the the the the the , , the , the the the the the the the the the the , the the the , , , , the the the , , the , the , the the , the , , the , the , the the , , the , the , , , , , , the the , the the , , , the the the , the the the , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.043478260238657855, 'p': 0.6666666666666666, 'r': 0.02247191011235955}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.02249658154089033, 'p': 0.6666666666666666, 'r': 0.02247191011235955}}
# epoch: 2, loss: 615.58, time: 10.36 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# broke , the the , , the the , , , , , the , , , , , , , the the the , the the , , the the , , the , the the the , the the freddie , , the , the the the the the the the the the the , , , , , , , , the the the , , , , the , the cambridge , the cambridge , cambridge , the , the cambridge , , the , , , , , , , , the cambridge , the cambridge , , , the the , , the the the , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.042553190482118634, 'p': 0.4, 'r': 0.02247191011235955}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.022538838793131233, 'p': 0.4, 'r': 0.02247191011235955}}
# epoch: 3, loss: 573.17, time: 10.53 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# broke soon the netflix , , the 200 , , , , , , , , , , , , , the the , , , the , , the the , , the , the the the , , , according , , the , the the the the the , the , the according , the , , , , , , the the the , , , , the , the according , s s , according , the , the according , , the , , , , , , , , the the , the cambridge , , , the the the , the the the the the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.061224488127863436, 'p': 0.3333333333333333, 'r': 0.033707865168539325}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.03401738420685932, 'p': 0.3333333333333333, 'r': 0.033707865168539325}}
# epoch: 4, loss: 535.45, time: 10.60 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# broke , a billboard 200 , 200 200 , , 200 200 , 200 been crying been been , been , " 200 the , the the , the the 200 , the the , the the the the the the the , , the , the the the the the the the the the according , the , , , , according , but " said , , " , but , the according , s totally , according , said , according 200 , , the , said , , , , , , but 200 , the university , , , but the according , the the the , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.09615384368528113, 'p': 0.3333333333333333, 'r': 0.056179775280898875}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.04600024846688853, 'p': 0.26666666666666666, 'r': 0.0449438202247191}}
# epoch: 5, loss: 484.40, time: 10.57 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# broke : the new , , the university , , second , , , been been been been been been , " been been , the been , the the search , , the , the facebook the , facebook , search , , facebook , the , the the search , the , the sell , the , , , , , , " , " , . , , " , the university , s grand , sell , " , the search , , the , , , . , , , , the search , the search , , , " the the , the the the , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.058252424835517104, 'p': 0.21428571428571427, 'r': 0.033707865168539325}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.03440801567870942, 'p': 0.21428571428571427, 'r': 0.033707865168539325}}
# epoch: 6, loss: 443.85, time: 10.47 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ##ex : the billboard , , the city , , has , , , been been been strides been been , but been been , the the , the the french . , the . the the the . the . location . . facebook . the . the the search , the . the search , the , , , , . , " , the . . . . " , the search , s grand , child , the , the search , , the . , , . , . , , the search , the search , , , " , , . the the the , the . . . . . . . . . . . . . . . . . . , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.0925925896930728, 'p': 0.2631578947368421, 'r': 0.056179775280898875}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.05817416566929502, 'p': 0.2631578947368421, 'r': 0.056179775280898875}}
# epoch: 7, loss: 400.09, time: 10.29 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ##ex for the billboard has , the city , , , , , , , county pat been been been , but been been for the the for the the location for to the for the facebook the to la the location to to facebook to according to the the facebook to the the the facebook , the , , , , , , " , according , . , , according , the university , s grand , yard , said , the search , , the , , , . , , , , the search , the museum , , , " the la , the the the , the , . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.10526315447060644, 'p': 0.24, 'r': 0.06741573033707865}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.05929830112388082, 'p': 0.2, 'r': 0.056179775280898875}}
# epoch: 8, loss: 355.58, time: 10.27 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ##ex the the billboard ##ship , the chancellor , , , , , , , been , been has been , the been been for the the to the the french to to the to the the the to the the location to to facebook , the , , the facebook , the , the chancellor , , , , , , , , the , the , . , , the , the university , s grand , trustees , the , the search , , the , , , . , , , , the museum , the museum , , , but the the , the the the , the . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.10909090600165298, 'p': 0.2857142857142857, 'r': 0.06741573033707865}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.07024627920984775, 'p': 0.2857142857142857, 'r': 0.06741573033707865}}
# epoch: 9, loss: 317.97, time: 10.27 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# march ##see the chancellor ##ship has the university , , york york , , been been been been been been , but been been to to been to to the search has to the , the has the to talk to search to to facebook to the , to the search , the , said search , has , , , , children , but , said , . , , , , the university , s board , trustees , said , the search , , , , , , . , , , , the search , the search , children , but , , , the the the , the . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.09090908781983482, 'p': 0.23809523809523808, 'r': 0.056179775280898875}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.05853856600821801, 'p': 0.23809523809523808, 'r': 0.056179775280898875}}
# epoch: 10, loss: 278.92, time: 10.29 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# march ##see application chancellor ##ship , the chancellor , , york york , , been whom been been been been , the been invited to the round to the the search , the the , the the la to round the search to to the , the , the the search , the , the chancellor , , , , , , weeks , the , former , . , , 000 , the university , s board , board , former , the search , , , , , , , , , , , the chancellor , the search , , , , , spring , the the the , the , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.054054050875740785, 'p': 0.13636363636363635, 'r': 0.033707865168539325}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.03523532839501125, 'p': 0.13636363636363635, 'r': 0.033707865168539325}}
# epoch: 11, loss: 241.24, time: 10.27 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the first ##ship the the university , , university york , , to whom to been interviewed interviewed , the been invited in in new in the the search round the the , the round round to round the final round to interviews to the , to the search , the , the chancellor , , , in , in weeks , the , said , . , , said , the university , s board , trustees , said , the university , , the , , , . , , , , the chancellor , the university - years , said , new , the new retire in the . . , , , , , , , , , , , , , , , , , , , , , ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan , , ##zan , , ,
# rouge {'rouge-1': {'f': 0.10169491154696939, 'p': 0.20689655172413793, 'r': 0.06741573033707865}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.07207982911008237, 'p': 0.20689655172413793, 'r': 0.06741573033707865}}
# epoch: 12, loss: 210.14, time: 10.43 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship the the university university , york york , , been whom been previously previously interviewed in the been invited in for round individually the the search round to round to the round la to round the final round of interviews to according close to the search close the this said search , round chosen chosen to the weeks , according , former , . , , chairman ##son search search , s board ##son trustees , nfl , the search , . the . , , . , , , , the chancellor , the search men men , the the last , the retire retire in the . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.09374999576293964, 'p': 0.15384615384615385, 'r': 0.06741573033707865}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.07412389047070618, 'p': 0.15384615384615385, 'r': 0.06741573033707865}}
# epoch: 13, loss: 188.07, time: 10.48 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship the the chancellor university , , york , , been whom been previously interviewed interviewed , but been invited in individually new individually this the search committee this weekend , the round expected to new this final round of interviews to according close to the search close facebook . said chancellor , new chosen chosen to of weeks , according said said . . murphy , said , the search , s board of trustees , said , the search , . said . robert ##son . ki ##bbe , , the chancellor , the last years years , said , spring . the retire retire in the . . . , , , , , , , , , , , , , , , , , , , , , ##zan , ##zan ##zan , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.10370369921097412, 'p': 0.15217391304347827, 'r': 0.07865168539325842}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.08757143480353673, 'p': 0.15217391304347827, 'r': 0.07865168539325842}}
# epoch: 14, loss: 168.84, time: 10.43 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the first ##ship the the first university , york york , but been whom been previously interviewed interviewed , the been invited in to new in the the search committee on weekend on the the expected to interviews the final to to interviews to the to to the search to the the the chancellor to walter to chosen to the weeks , the to the , . murphy , the , the search , s board of trustees , offensive , the search committee . the . robert , . , ##bbe , , the chancellor , the search 10 years , the the spring , the retire retire in the . . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.10852712750435686, 'p': 0.175, 'r': 0.07865168539325842}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0866705940032345, 'p': 0.175, 'r': 0.07865168539325842}}
# epoch: 15, loss: 149.78, time: 10.47 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the first ##ship of the university university university university york , is previously whom previously previously previously interviewed interviewed the invited invited invited individually expected individually this the search committee within expected this the round expected expected talk chosen final round of interviews to according close close the final close the this said chancellor will chosen chosen chosen within of weeks of according to chancellor p . murphy , chairman of the university ' s board of trustees of trustees of the search committee . the . robert ##son . ki ##bbe and is the chancellor last the last 10 years of the the spring . the retire retire retire the . . , , , , , , , , , , , , , , , four four four four four , four ##zan , ##zan ##zan ##zan ##zan ##zan , , , , , , , , four , , ,
# rouge {'rouge-1': {'f': 0.11428570965408182, 'p': 0.1568627450980392, 'r': 0.0898876404494382}, 'rouge-2': {'f': 0.00956937299970499, 'p': 0.01, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.10049425753923985, 'p': 0.1568627450980392, 'r': 0.0898876404494382}}
# epoch: 16, loss: 140.53, time: 10.44 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship the the first university , york york , the been whom been been interviewed interviewed , but been invited in to weekend in to the search committee to weekend , the this weekend to be the final round of interviews to according to to the search to that , said chancellor , probably to to to the weeks , according to said , . murphy , chairman , the search ' s board ' trustees , offensive to the search committee . said . robert , . ki ##bbe , , the chancellor , the last 10 years , said the spring , the would her in the . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.10370369921097412, 'p': 0.15217391304347827, 'r': 0.07865168539325842}, 'rouge-2': {'f': 0.010101005152027727, 'p': 0.011235955056179775, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.08757143480353673, 'p': 0.15217391304347827, 'r': 0.07865168539325842}}
# epoch: 17, loss: 124.04, time: 10.72 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship of the city university , is york , , been whom with previously interviewed interviewed , been been invited in to weekend individually this the search committee in weekend , the this expected to be the final - of interviews to according close to the search , the . said chancellor , chosen within chosen within in weeks , according to dr . . murphy , chairman , the university , s board of trustees , afghan , the search committee . the . ki , . , ##bbe , , the chancellor , the last 10 years , said the spring . the retire retire in . . . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.11594202440558725, 'p': 0.16326530612244897, 'r': 0.0898876404494382}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.1003819512824096, 'p': 0.16326530612244897, 'r': 0.0898876404494382}}
# epoch: 18, loss: 110.11, time: 10.41 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship of the city university , york york , announced of whom of previously previously been , but been invited back back expected individually this the search committee of weekend , the close expected to be this final round of interviews , sources close close the search close . . said chancellor , probably within chosen within of weeks of " to said . . murphy , chairman of the university ' s board of trustees . offensive of the search committee . murphy . robert j . ki ##bbe , , chairman search , the last 10 years , said that spring . have be retire in . . . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.09722221750096473, 'p': 0.12727272727272726, 'r': 0.07865168539325842}, 'rouge-2': {'f': 0.00956937299970499, 'p': 0.01, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.08793541930624461, 'p': 0.12727272727272726, 'r': 0.07865168539325842}}
# epoch: 19, loss: 100.49, time: 10.33 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship of the university university , university york , , to whom of previously interviewed interviewed , the back invited in to individually individually to the search committee of weekend , the du expected to be the final round of interviews , sources to to the search , yesterday . said chancellor will probably will chosen to in weeks . the to dr . . murphy , chairman , the university ' s board . trustees . head . the search committee . dr . robert j . ki ##bbe , , the chancellor , the last 10 years . said that spring . the retire retire in . . . . , , , , , , , , , , , , , , , , , , , , , , , ##zan ##zan ##zan ##zan ##zan , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.09929077548614276, 'p': 0.1346153846153846, 'r': 0.07865168539325842}, 'rouge-2': {'f': 0.009803916592178613, 'p': 0.010526315789473684, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.08795769042915026, 'p': 0.1346153846153846, 'r': 0.07865168539325842}}
# epoch: 20, loss: 89.02, time: 10.38 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship of the city university , city york , , previously whom previously previously previously interviewed , but been invited in in expected in this the search committee in weekend , the weekend expected to be the final round of interviews , sources close to the chancellor , the , the chancellor , probably within chosen within in weeks in the to robert p . murphy , chairman , the university , s board of trustees . the of the search committee . robert . robert j . ki ##bbe ##e , the chancellor , the last 10 years , the that spring . the is retire in . . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.11428570965408182, 'p': 0.1568627450980392, 'r': 0.0898876404494382}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.10049425753923985, 'p': 0.1568627450980392, 'r': 0.0898876404494382}}
# epoch: 21, loss: 75.01, time: 10.37 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the university university , university york , is been whom been been back interviewed , been been invited back individually individually individually with the search committee in weekend , its weekend expected to probably individually final round of interviews to sources close to the search close yesterday . in chancellor will probably to chosen within in weeks . according to search p . murphy , chairman of the university ' s board of trustees . head of the search committee . dr . ki j . ki ##bbe ##e , the search will the search 10 years , said that spring . that retire retire in . . . . , , , , , , , , , , , , ##e ##e ##e , , ##e , , , ##zan , ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan , ,
# rouge {'rouge-1': {'f': 0.15068492674704462, 'p': 0.19298245614035087, 'r': 0.12359550561797752}, 'rouge-2': {'f': 0.009478667991287642, 'p': 0.00980392156862745, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.11293449956295354, 'p': 0.15789473684210525, 'r': 0.10112359550561797}}
# epoch: 22, loss: 65.73, time: 10.40 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship of the city university , city york , announced of whom previously previously previously interviewed , with been invited back to meet in with the search committee with weekend , the meet expected to be the final round of interviews , sources close to the search that yesterday . a chancellor will probably be chosen within of weeks of according to chancellor p . murphy , chairman of the university ' s board of trustees of chairman of the search committee . murphy . robert j . robert ##bbe ##e , the chancellor , the last 10 years , said last spring that that would retire in july . . . , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.12162161682706374, 'p': 0.15254237288135594, 'r': 0.10112359550561797}, 'rouge-2': {'f': 0.009523804531068375, 'p': 0.009900990099009901, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.11272392535594389, 'p': 0.15254237288135594, 'r': 0.10112359550561797}}
# epoch: 23, loss: 54.32, time: 10.38 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , is of whom had been been interviewed , with been invited back to new individually with the search committee with weekend to its what expected to be the final round of interviews to sources close to the search close yesterday . in chancellor will probably be chosen within of weeks of according to dr p . murphy , chairman of the university ' s board of trustees of head of the search committee . dr . robert j . ki ##bbe ##e , the search of the last 10 years , said last spring that that would retire in july . . . , of of of ##e ##e ##e ##e ##e ##e ##e ##e ##e ##e ##e ##e ##e ##e ##e ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan ##zan , , , , ##zan , , ,
# rouge {'rouge-1': {'f': 0.14193547898106157, 'p': 0.16666666666666666, 'r': 0.12359550561797752}, 'rouge-2': {'f': 0.009049768756580227, 'p': 0.008928571428571428, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.12370209528781956, 'p': 0.15151515151515152, 'r': 0.11235955056179775}}
# epoch: 24, loss: 44.86, time: 10.38 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates the the chancellor ##ship of the city university of city york , is of whom been previously been interviewed , been been invited back to meet individually with the search committee this weekend this the what expected to be the final round of interviews , sources close to the search that yesterday . a chancellor will probably be chosen within of weeks of according to dr p . murphy , chairman of the university ' s board of trustees of head of the search committee . dr . robert j . ki ##bbe ##e said the chancellor of the last 10 years , said last spring that the would retire in july . . . , of of of of of of , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.12987012499156708, 'p': 0.15384615384615385, 'r': 0.11235955056179775}, 'rouge-2': {'f': 0.009259254259690626, 'p': 0.009345794392523364, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.11159112856943072, 'p': 0.13846153846153847, 'r': 0.10112359550561797}}
# epoch: 25, loss: 35.16, time: 10.35 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , is of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend this what what expected to be the final round of interviews , sources close to the search close yesterday . a chancellor will probably be chosen within of weeks , according to james p . murphy , chairman of the university ' s board of trustees of head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor of the last 10 years , said last spring that he would retire in july . . . ##e of of of of of of of of of of of of of of of of of , , , , , , , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.13749999506328142, 'p': 0.15492957746478872, 'r': 0.12359550561797752}, 'rouge-2': {'f': 0.009259254259690626, 'p': 0.009345794392523364, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.10975651061242277, 'p': 0.1267605633802817, 'r': 0.10112359550561797}}
# epoch: 26, loss: 27.04, time: 10.36 sec
# ####################################################
# ########################Train######################
# ...
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009302320582371534, 'p': 0.009433962264150943, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 77, loss: 0.14, time: 10.40 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan ##zan , , , , , , , , , , , ##zan , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009302320582371534, 'p': 0.009433962264150943, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 78, loss: 0.13, time: 10.34 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009345789394272915, 'p': 0.009523809523809525, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 79, loss: 0.12, time: 10.28 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009345789394272915, 'p': 0.009523809523809525, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 80, loss: 0.11, time: 10.35 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan ##zan , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009302320582371534, 'p': 0.009433962264150943, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 81, loss: 0.11, time: 10.35 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009345789394272915, 'p': 0.009523809523809525, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 82, loss: 0.10, time: 10.41 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan ##zan , , , , , , , , , , , ##zan , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009302320582371534, 'p': 0.009433962264150943, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 83, loss: 0.09, time: 10.46 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan , , , , , , , , , , , , , , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009345789394272915, 'p': 0.009523809523809525, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 84, loss: 0.09, time: 10.46 sec
# ####################################################
# ########################Train######################
# pope ##ye - worthy pie . ph ##yl ##lo dough wraps spin ##ach in pure gold by rosemary black spin ##ach has terror ##ized generations of ve ##gg ##ie - ph ##ob ##ic kids , and many grown ##ups don ' t much like it , either . but when it ' s combined with season ##ings and fe ##ta cheese and wrapped in a golden crisp ph ##yl ##lo dough crust , even those who des ##pis ##e pope ##ye ' s af ##av ##ori ##te food ask for seconds . the spin ##ach pie at ke ##ba ##b house ii on orchard st . is a specialty of owner and executive chef rama ##zan a ##y , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# candidates for the chancellor ##ship of the city university of new york , all of whom had previously been interviewed , have been invited back to meet individually with the search committee this weekend for what is expected to be the final round of interviews , sources close to the search said yesterday . a chancellor will probably be chosen within two weeks , according to james p . murphy , chairman of the university ' s board of trustees and head of the search committee . dr . robert j . ki ##bbe ##e , the chancellor for the last 10 years , said last spring that he would retire this july . . , , , , , , , , , , , , , , , , , , , , , , , , ##zan ##zan , , , , , , , , , , , ##zan , , ,
# rouge {'rouge-1': {'f': 0.14723925884602374, 'p': 0.16216216216216217, 'r': 0.1348314606741573}, 'rouge-2': {'f': 0.009302320582371534, 'p': 0.009433962264150943, 'r': 0.009174311926605505}, 'rouge-l': {'f': 0.13273998304769452, 'p': 0.14864864864864866, 'r': 0.12359550561797752}}
# epoch: 85, loss: 0.08, time: 10.45 sec
# ####################################################
